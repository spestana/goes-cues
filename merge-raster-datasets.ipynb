# %% [markdown]
# # GOES ABI, MODIS, ASTER Comparison
# ## Compute summary statistics for their ~11 micron TIR bands

# %%
import pandas as pd
import numpy as np
from scipy import stats
import xarray as xr
import os
import glob

# for plotting
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib_scalebar.scalebar import ScaleBar
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
# %matplotlib inline

# for plotting ASTER geotiffs
import rasterio as rio
import rasterio.plot as rioplt
from rasterio.warp import calculate_default_transform

# for working with raster data
import rioxarray

# for shapefile
import geopandas as gpd

# for MODIS conversions
import modis_utils

# for calculating zonal statistics
import aster_utils

# for GOES
import goes_utils

import warnings
warnings.filterwarnings('ignore')

# %%
def summary_stats(a, b):
    '''Compute summary statistics for the difference between two sets.
    Input two flattened (1-D) arrays with NaN values removed'''
    
    # remove nan values
    a = a[np.isnan(a)==False]
    b = b[np.isnan(b)==False]
    
    # for difference stats
    diff = b - a
    
    # for linear regression stats
    slope, intercept, r_value, p_value, std_err = stats.linregress(a, b)
    
    # populate dict with summary stats
    summary_stats_dict = {
        #'diff' : diff ,
        'n' : len(diff) ,
        'mean_diff' : np.nanmean( diff ),
        'median_diff' : np.nanmedian( diff ),
        'mean_squared_diff' : np.nanmean( diff**2 ),
        'rms_diff' : np.sqrt( np.nanmean( diff**2 ) ),
        'std_diff' : np.nanstd( diff ),
        'slope' : slope,
        'intercept' : intercept,
        'r_value' : r_value,
        'p_value' : p_value,
        'std_err' : std_err
        }
    
    return summary_stats_dict

# %% [markdown]
# Set font sizes for plots

# %%
SMALL_SIZE = 12
MEDIUM_SIZE = 16
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %% [markdown]
# Define some funcitons I'll use below

# %%
# use this function to match the date/time of observations
def nearest(items, pivot):
    # https://stackoverflow.com/questions/32237862/find-the-closest-date-to-a-given-date
    return min(items, key=lambda x: abs(x - pivot))

# %% [markdown]
# ---
# ### Find GOES ABI, MODIS, and ASTER image triplets

# %% [markdown]
# Get filepaths for ASTER images

# %%
aster_directory = "/storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/"
# Find all our ASTER files and their timestamps in our directory
df = aster_utils.aster_timestamps(aster_directory, ext='tif')
# add a UTC-8 datetime for pacific standard that CUES uses
df['datetime'] = df.timestampUTC - pd.Timedelta(hours=8)
# save a csv file of the ASTER files we are using
#aster.to_csv('aster_AST_L1T_band14_Tuolumne-and-CUES.csv')

# %% [markdown]
# Get filepaths for orthorectified GOES brightness temperature, radiance images and "zone_labels"

# %%
goes_directory = "/storage/GOES/orthorectified"
#ortho_goes_tb_filelist = glob.glob(goes_directory + '/**/*_orthorectified_tb.tif', recursive=True)
#ortho_goes_rad_filelist = glob.glob(goes_directory + '/**/*_orthorectified_Rad.tif', recursive=True)
#ortho_goes_zones_filelist = glob.glob(goes_directory + '/**/*_orthorectified_zone_labels.tif', recursive=True)
ortho_goes_tb_filelist = glob.glob(goes_directory + '/**/*_original_tb.tif', recursive=True)
ortho_goes_rad_filelist = glob.glob(goes_directory + '/**/*_original_Rad.tif', recursive=True)
ortho_goes_zones_filelist = glob.glob(goes_directory + '/**/*_original_zone_labels.tif', recursive=True)

# %% [markdown]
# Find the GOES Brightness Temperature observations at the same time as ASTER

# %%
goes_tb_dict = goes_utils.goes_timestamps(ortho_goes_tb_filelist)

# %% [markdown]
# Find the GOES Radiance observations at the same time as ASTER

# %%
goes_rad_dict = goes_utils.goes_timestamps(ortho_goes_rad_filelist)

# %% [markdown]
# Find the GOES "zone_labels" files at the same time as ASTER

# %%
goes_zones_dict = goes_utils.goes_timestamps(ortho_goes_zones_filelist)

# %% [markdown]
# Match GOES ABI images with corresponding ASTER image

# %%
df['goes_timestampUTC'] = df.timestampUTC
df['goes_tb_filepath'] = df.filepath
df['goes_rad_filepath'] = df.filepath
df['goes_zones_filepath'] = df.filepath

for i in range(len(df)):
    nearest_goes_timestampUTC = nearest(list(goes_rad_dict.keys()), df.timestampUTC[i])
    #print('ASTER: {}\nGOES: {}\n\n'.format(df.timestampUTC[i], nearest_goes_timestampUTC))
    df['goes_timestampUTC'][i] = nearest_goes_timestampUTC
    df['goes_rad_filepath'][i] = goes_rad_dict[nearest_goes_timestampUTC]['filepath']
    nearest_goes_tb_timestampUTC = nearest(list(goes_tb_dict.keys()), df.timestampUTC[i])
    df['goes_tb_filepath'][i] = goes_tb_dict[nearest_goes_tb_timestampUTC]['filepath']
    nearest_goes_zone_timestampUTC = nearest(list(goes_zones_dict.keys()), df.timestampUTC[i])
    df['goes_zones_filepath'][i] = goes_zones_dict[nearest_goes_zone_timestampUTC]['filepath']

# make anoter column of UTC-8 (PST) times:
df['goes_timestampPST'] = df.goes_timestampUTC - pd.Timedelta(hours=8)

# %% [markdown]
# Get filepaths for the MODIS observations I've created NetCDF files for, and their corresponding timestamps:

# %%
# search for MODIS files in this directory
modis_dir = '/storage/MODIS/Tuolumne_MOD021KM/'
# get .tif files here
modis_filelist = glob.glob(modis_dir + '*.tif', recursive=True)

# create an empty dictionary we'll fill with filenames and timestamps for each modis image we have
modis_dict = {}

for this_modis_file in modis_filelist:
    # get just the filename
    this_modis_filename = os.path.normpath(this_modis_file).split('/')[-1]
    # then parse the year, day of year, hour, and minutes from the filename
    this_modis_date_time = this_modis_filename.split('.')[1] + this_modis_filename.split('.')[2]
    this_modis_timestampUTC = pd.to_datetime(this_modis_date_time[1:], format="%Y%j%H%M")
    this_modis_timestampUTC = pd.Timestamp(this_modis_timestampUTC, tz='UTC') #also specify UTC
    # add these to our dictionary, use the date as the key
    modis_dict[this_modis_timestampUTC] = {}
    modis_dict[this_modis_timestampUTC]['filepath'] = this_modis_file

# %% [markdown]
# Match ASTER with it's corresponding MODIS image:

# %%
df['modis_timestampUTC'] = df.timestampUTC
df['modis_filepath'] = df.filepath

for i in range(len(df)):
    nearest_modis_timestampUTC = nearest(list(modis_dict.keys()), df.timestampUTC[i])
    #print('ASTER: {}\nMODIS: {}\n\n'.format(df.timestampUTC[i], nearest_modis_timestampUTC))
    df['modis_timestampUTC'][i] = nearest_modis_timestampUTC
    df['modis_filepath'][i] = modis_dict[nearest_modis_timestampUTC]['filepath']
    
# make anoter column for MODIS UTC-8 (PST) times:
df['modis_timestampPST'] = df.modis_timestampUTC - pd.Timedelta(hours=8)

# %%
# preview dataframe
df.head(3)
# Out:
#                timestampUTC  \
# 0 2017-04-21 18:51:07+00:00
# 1 2017-05-23 18:51:10+00:00
# 2 2017-06-07 06:07:10+00:00
#
#                                             filepath  \
# 0  /storage/spestana/ASTER/AST_L1T/geotiff/T/T_ba...
# 1  /storage/spestana/ASTER/AST_L1T/geotiff/T/T_ba...
# 2  /storage/spestana/ASTER/AST_L1T/geotiff/T/T_ba...
#
#                    datetime         goes_timestampUTC  \
# 0 2017-04-21 10:51:07+00:00 2017-04-21 18:50:02+00:00
# 1 2017-05-23 10:51:10+00:00 2017-05-23 18:29:45+00:00
# 2 2017-06-06 22:07:10+00:00 2017-06-07 06:04:56+00:00
#
#                                     goes_tb_filepath  \
# 0  /storage/GOES/orthorectified/2017/04/21/ABI-L1...
# 1  /storage/GOES/orthorectified/2017/05/23/ABI-L1...
# 2  /storage/GOES/orthorectified/2017/06/7/ABI-L1b...
#
#                                    goes_rad_filepath  \
# 0  /storage/GOES/orthorectified/2017/04/21/ABI-L1...
# 1  /storage/GOES/orthorectified/2017/05/23/ABI-L1...
# 2  /storage/GOES/orthorectified/2017/06/7/ABI-L1b...
#
#                                  goes_zones_filepath  \
# 0  /storage/GOES/orthorectified/2017/04/21/ABI-L1...
# 1  /storage/GOES/orthorectified/2017/05/23/ABI-L1...
# 2  /storage/GOES/orthorectified/2017/06/7/ABI-L1b...
#
#           goes_timestampPST        modis_timestampUTC  \
# 0 2017-04-21 10:50:02+00:00 2017-04-21 18:50:00+00:00
# 1 2017-05-23 10:29:45+00:00 2017-05-23 18:50:00+00:00
# 2 2017-06-06 22:04:56+00:00 2017-06-07 06:05:00+00:00
#
#                                       modis_filepath        modis_timestampPST
# 0  /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A201... 2017-04-21 10:50:00+00:00
# 1  /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A201... 2017-05-23 10:50:00+00:00
# 2  /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A201... 2017-06-06 22:05:00+00:00

# %% [markdown]
# Save out dataframe with image triplet filepaths and timestamps to csv file:

# %%
#df.to_csv('goes_orthorectified_tb_rad_zones-modis-aster-list.csv')
df.to_csv('goes_original_tb_rad_zones-modis-aster-list.csv')

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# ## Compute summary statistics
#
# #### And optionally make overview plots

# %% [markdown]
# Define a working area to clip all three rasters to the same common area before computing summary statistics:

# %%
# Define a working area here in local UTM coordinates to clip all three rasters to the same common area

## Area around Tuolumne
#utm_northings_max = 4205000
#utm_northings_min = 4185000
#utm_eastings_max = 305000
#utm_eastings_min = 285000

# Larger area around Tuolumne further south and east to include Mammoth
utm_northings_max = 4205000
utm_northings_min = 4140000
utm_eastings_max = 320000
utm_eastings_min = 285000


geometry = [
    {
        'type': 'Polygon',
        'coordinates': [[
            [utm_eastings_min, utm_northings_max],
            [utm_eastings_max, utm_northings_max],
            [utm_eastings_max, utm_northings_min],
            [utm_eastings_min, utm_northings_min]
        ]]
    }
]

# %% [markdown]
# Load image triplets, compute summary statistics:

# %%
# Set up file output options
output_filename_prefix = 'ASTER-MODIS-GOES_'
#output_filename_suffix = '_orthorectified.nc'
output_filename_suffix = '_original.nc'
aster_modis_zonalstats_df_output_filename_suffix = '_aster_modis_zonalstats.nc'
aster_goes_zonalstats_df_output_filename_suffix = '_aster_goes_zonalstats.nc'
output_dir = '/storage/spestana/output_ASTER-MODIS-GOES/'

# Make an empty list to hold all the resulting datasets
#ds_list = []


# pick one set of images from our list
for n in range(len(df)):
    print('{} of {}'.format(n,len(df)))
    
    # Zonal statistics between ASTER and GOES
    print('Zonal stats between ASTER and GOES\n{}\n{}'.format(df.filepath[n],df.goes_rad_filepath[n]))
    (aster_goes_ds, _) = aster_utils.upscale_aster_goes_rad_zonal_stats(aster_rad_filepath = df.filepath[n], 
                                                                   goes_rad_filepath = df.goes_rad_filepath[n], 
                                                                   goes_zones_filepath = df.goes_zones_filepath[n],
                                                                   goes_tb_filepath = df.goes_tb_filepath[n],
                                                                   bounding_geometry=None,
                                                                   output_filepath=None)
    
    # Zonal statistics between ASTER and MODIS
    print('Zonal stats between ASTER and MODIS\n{}\n{}'.format(df.filepath[n],df.modis_filepath[n]))
    (aster_modis_ds, _) = aster_utils.upscale_aster_modis_rad_zonal_stats(aster_rad_filepath = df.filepath[n],
                                                                     modis_rad_filepath = df.modis_filepath[n], 
                                                                     bounding_geometry=None, 
                                                                     modis_band_index=10, 
                                                                     output_filepath=None)
    
    print('Fixing data variable and attribute names to avoid merge conflicts and invalid characters')
    # rename data variables to avoid conflict on merge
    for key in aster_goes_ds.keys():
        aster_goes_ds = aster_goes_ds.rename({key: 'ast_goes_'+key})
    for key in aster_modis_ds.keys():
        aster_modis_ds = aster_modis_ds.rename({key: 'ast_mod_'+key})
    # remove % and " " characters from attributes
    for da in aster_modis_ds:
        for attr_key in aster_modis_ds[da].attrs.keys():
            new_atr_key = attr_key.replace('%', '').replace(' ', '')
            aster_modis_ds[da].attrs[new_atr_key] = aster_modis_ds[da].attrs.pop(attr_key)
    
    # Merge both datasets
    print('Merging datasets...')
    ds = xr.merge([aster_goes_ds, aster_modis_ds])
    
    # Add time dimension
    print('Add time UTC dimension')
    ds = ds.expand_dims({'time': [ df.timestampUTC[n] ]})
    
    
    # Add attributes to dataset
    print('Add attributes to dataset')
    ds.attrs['aster_rad_filepath'] = df.filepath[n]
    ds.attrs['modis_rad_filepath'] = df.modis_filepath[n]
    ds.attrs['goes_rad_filepath'] = df.goes_rad_filepath[n]
    ds.attrs['goes_zones_filepath'] = df.goes_zones_filepath[n]
    ds.attrs['goes_tb_filepath'] = df.goes_tb_filepath[n]
    
    # Set up filename for output
    output_filename_timestamp = df.timestampUTC[n].strftime('%Y-%m-%dT%H%M%SUTC')
    output_filepath = output_dir + output_filename_prefix + output_filename_timestamp + output_filename_suffix   

    print('Export to NetCDF file...')
    # export to netcdf file
    ds.to_netcdf(output_filepath)
    print('Moving onto next...')
# Out:
# 0 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00304212017185107_20170422082541_26960_ImageData14.tif
# /storage/GOES/orthorectified/2017/04/21/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M4C14_G16_s20171111845222_e20171111850023_c20171111850035_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00304212017185107_20170422082541_26960_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2017111.1850.061.2017314062948.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 1 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00305232017185110_20170524170415_26127_ImageData14.tif
# /storage/GOES/orthorectified/2017/05/23/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M3C14_G16_s20171431827078_e20171431829451_c20171431829492_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00305232017185110_20170524170415_26127_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2017143.1850.061.2017314142140.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 2 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306072017060710_20170608103007_26281_ImageData14.tif
# /storage/GOES/orthorectified/2017/06/7/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M3C14_G16_s20171580602189_e20171580604562_c20171580605006_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306072017060710_20170608103007_26281_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2017158.0605.061.2017314235847.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 3 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306072017060719_20170608114206_30429_ImageData14.tif
# /storage/GOES/orthorectified/2017/06/7/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M3C14_G16_s20171580602189_e20171580604562_c20171580605006_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306072017060719_20170608114206_30429_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2017158.0605.061.2017314235847.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 4 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306162017060108_20170617112734_28663_ImageData14.tif
# /storage/GOES/orthorectified/2017/06/16/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M3C14_G16_s20171670602149_e20171670604522_c20171670604571_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306162017060108_20170617112734_28663_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2017167.0600.061.2017315012504.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 5 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00309212017184530_20170922115100_5803_ImageData14.tif
# /storage/GOES/orthorectified/2017/09/21/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M3C14_G16_s20172641842222_e20172641844595_c20172641845038_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00309212017184530_20170922115100_5803_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2017264.1845.061.2017265073657.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 6 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00311072017060115_20171108151241_15811_ImageData14.tif
# /storage/GOES/orthorectified/2017/11/7/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M3C14_G16_s20173110602191_e20173110604564_c20173110605008_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00311072017060115_20171108151241_15811_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2017311.0600.061.2017311193824.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 7 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00311302017060713_20171201114713_10172_ImageData14.tif
# /storage/GOES/orthorectified/2017/11/30/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M3C14_G16_s20173340602193_e20173340604565_c20173340605012_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00311302017060713_20171201114713_10172_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2017334.0605.061.2017334192136.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 8 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00311302017060722_20171201114503_5669_ImageData14.tif
# /storage/GOES/orthorectified/2017/11/30/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M3C14_G16_s20173340602193_e20173340604565_c20173340605012_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00311302017060722_20171201114503_5669_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2017334.0605.061.2017334192136.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 9 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00301032018055458_20180104122052_7153_ImageData14.tif
# /storage/GOES/orthorectified/2018/01/3/ABI-L1b-RadC/05/C14/OR_ABI-L1b-RadC-M3C14_G16_s20180030552203_e20180030554576_c20180030555025_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00301032018055458_20180104122052_7153_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2018003.0555.061.2018003133112.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 10 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00303232018185127_20180324090217_12711_ImageData14.tif
# /storage/GOES/orthorectified/2018/03/23/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M3C14_G16_s20180821847261_e20180821850034_c20180821850083_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00303232018185127_20180324090217_12711_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2018082.1850.061.2018083074842.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 11 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00304082018185146_20180409113518_2804_ImageData14.tif
# /storage/GOES/orthorectified/2018/04/8/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M3C14_G16_s20180981847219_e20180981849591_c20180981850046_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00304082018185146_20180409113518_2804_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2018098.1850.061.2018099073216.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 12 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00305172018185831_20180518114917_21406_ImageData14.tif
# /storage/GOES/orthorectified/2018/05/17/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M3C14_G16_s20181371857224_e20181371859597_c20181371900038_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00305172018185831_20180518114917_21406_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2018137.1855.061.2018138100943.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 13 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306022018185839_20180603133217_19253_ImageData14.tif
# /storage/GOES/orthorectified/2018/06/2/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M3C14_G16_s20181531857290_e20181531900063_c20181531900111_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306022018185839_20180603133217_19253_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2018153.1855.061.2018154074930.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 14 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306032018060225_20180604142908_29333_ImageData14.tif
# /storage/GOES/orthorectified/2018/06/3/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M3C14_G16_s20181540602292_e20181540605065_c20181540605111_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306032018060225_20180604142908_29333_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2018154.0600.061.2018154193339.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 15 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306042018184627_20180605120930_14256_ImageData14.tif
# /storage/GOES/orthorectified/2018/06/4/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M3C14_G16_s20181551842300_e20181551845073_c20181551845120_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306042018184627_20180605120930_14256_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2018155.1845.061.2018158141144.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 16 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00310102018184603_20181011114142_21756_ImageData14.tif
# /storage/GOES/orthorectified/2018/10/10/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M3C14_G16_s20182831842203_e20182831844576_c20182831845016_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00310102018184603_20181011114142_21756_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2018283.1845.061.2018284075253.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 17 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00310172018185200_20181018114910_29857_ImageData14.tif
# /storage/GOES/orthorectified/2018/10/17/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M3C14_G16_s20182901847203_e20182901849576_c20182901850015_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00310172018185200_20181018114910_29857_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2018290.1850.061.2018291073220.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 18 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00311012018060755_20181102132708_19530_ImageData14.tif
# /storage/GOES/orthorectified/2018/11/1/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M3C14_G16_s20183050607192_e20183050609564_c20183050610013_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00311012018060755_20181102132708_19530_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2018305.0605.061.2018305193436.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 19 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00311262018060119_20181128034140_15697_ImageData14.tif
# /storage/GOES/orthorectified/2018/11/26/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M3C14_G16_s20183300602183_e20183300604556_c20183300604599_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00311262018060119_20181128034140_15697_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2018330.0600.061.2018330201439.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 20 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00312192018060713_20181220102409_22456_ImageData14.tif
# /storage/GOES/orthorectified/2018/12/19/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M3C14_G16_s20183530602157_e20183530604530_c20183530604573_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00312192018060713_20181220102409_22456_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2018353.0605.061.2018353211621.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 21 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00312192018060722_20181220120621_7468_ImageData14.tif
# /storage/GOES/orthorectified/2018/12/19/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M3C14_G16_s20183530602157_e20183530604530_c20183530604573_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00312192018060722_20181220120621_7468_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2018353.0605.061.2018353211621.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 22 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00301132019060110_20190114102505_12350_ImageData14.tif
# /storage/GOES/orthorectified/2019/01/13/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M3C14_G16_s20190130602173_e20190130604546_c20190130604590_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00301132019060110_20190114102505_12350_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2019013.0600.061.2019013191932.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 23 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00303262019185120_20190327154236_27854_ImageData14.tif
# /storage/GOES/orthorectified/2019/03/26/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M3C14_G16_s20190851847164_e20190851849537_c20190851849577_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00303262019185120_20190327154236_27854_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2019085.1850.061.2019087190747.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 24 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00304272019185122_20190428120146_10912_ImageData14.tif
# /storage/GOES/orthorectified/2019/04/27/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M6C14_G16_s20191171846206_e20191171848579_c20191171849033_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00304272019185122_20190428120146_10912_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2019117.1850.061.2019118072514.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 25 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00305132019185122_20190514113020_26713_ImageData14.tif
# /storage/GOES/orthorectified/2019/05/13/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M6C14_G16_s20191331846295_e20191331849068_c20191331849112_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00305132019185122_20190514113020_26713_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2019133.1850.061.2019134071554.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 26 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00305282019060718_20190529145028_15219_ImageData14.tif
# /storage/GOES/orthorectified/2019/05/28/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M6C14_G16_s20191480606382_e20191480609155_c20191480609195_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00305282019060718_20190529145028_15219_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2019148.0605.061.2019148192440.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 27 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00305282019060727_20190529145038_15264_ImageData14.tif
# /storage/GOES/orthorectified/2019/05/28/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M6C14_G16_s20191480606382_e20191480609155_c20191480609195_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00305282019060727_20190529145038_15264_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2019148.0605.061.2019148192440.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 28 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306132019060713_20190614142250_19388_ImageData14.tif
# /storage/GOES/orthorectified/2019/06/13/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M6C14_G16_s20191640606486_e20191640609259_c20191640609313_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306132019060713_20190614142250_19388_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2019164.0605.061.2019165143652.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 29 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306132019060722_20190614142320_19993_ImageData14.tif
# /storage/GOES/orthorectified/2019/06/13/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M6C14_G16_s20191640606486_e20191640609259_c20191640609313_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306132019060722_20190614142320_19993_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2019164.0605.061.2019165143652.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 30 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306302019185106_20190702003645_5419_ImageData14.tif
# /storage/GOES/orthorectified/2019/06/30/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M6C14_G16_s20191811846238_e20191811849010_c20191811849061_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# ...
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 39 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00301232020060658_20200124112634_31598_ImageData14.tif
# /storage/GOES/orthorectified/2020/01/23/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M6C14_G16_s20200230606132_e20200230608505_c20200230608565_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00301232020060658_20200124112634_31598_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2020023.0605.061.2020027202949.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 40 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00301232020060707_20200124112644_31680_ImageData14.tif
# /storage/GOES/orthorectified/2020/01/23/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M6C14_G16_s20200230606132_e20200230608505_c20200230608565_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00301232020060707_20200124112644_31680_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2020023.0605.061.2020027202949.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 41 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00302012020060109_20200204130139_17864_ImageData14.tif
# /storage/GOES/orthorectified/2020/02/1/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M6C14_G16_s20200320601111_e20200320603484_c20200320603584_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00302012020060109_20200204130139_17864_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2020032.0600.061.2020032191658.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 42 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00302082020060729_20200209074710_19248_ImageData14.tif
# /storage/GOES/orthorectified/2020/02/8/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M6C14_G16_s20200390606059_e20200390608432_c20200390608481_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00302082020060729_20200209074710_19248_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2020039.0605.061.2020039191802.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 43 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00302262020055525_20200227083903_9621_ImageData14.tif
# /storage/GOES/orthorectified/2020/02/26/ABI-L1b-RadC/05/C14/OR_ABI-L1b-RadC-M6C14_G16_s20200570551151_e20200570553524_c20200570554065_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00302262020055525_20200227083903_9621_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2020057.0555.061.2020057131101.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 44 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00303052020184535_20200306091246_13096_ImageData14.tif
# /storage/GOES/orthorectified/2020/03/5/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M6C14_G16_s20200651841142_e20200651843515_c20200651844058_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00303052020184535_20200306091246_13096_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2020065.1845.061.2020066071347.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 45 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00304132020185117_20200414091306_12717_ImageData14.tif
# /storage/GOES/orthorectified/2020/04/13/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M6C14_G16_s20201041846134_e20201041848507_c20201041849002_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00304132020185117_20200414091306_12717_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2020104.1850.061.2020105070743.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 46 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00305152020185104_20200516101436_31724_ImageData14.tif
# /storage/GOES/orthorectified/2020/05/15/ABI-L1b-RadC/18/C14/OR_ABI-L1b-RadC-M6C14_G16_s20201361846119_e20201361848491_c20201361849009_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00305152020185104_20200516101436_31724_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2020136.1850.061.2020137064638.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 47 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306152020060700_20200616104305_10787_ImageData14.tif
# /storage/GOES/orthorectified/2020/06/15/ABI-L1b-RadC/06/C14/OR_ABI-L1b-RadC-M6C14_G16_s20201670606152_e20201670608525_c20201670609050_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306152020060700_20200616104305_10787_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2020167.0605.061.2020167221653.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
# 48 of 49
# Zonal stats between ASTER and GOES
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306172020055447_20200618110409_10687_ImageData14.tif
# /storage/GOES/orthorectified/2020/06/17/ABI-L1b-RadC/05/C14/OR_ABI-L1b-RadC-M6C14_G16_s20201690551158_e20201690553531_c20201690554030_original_Rad.tif
# >>>>>>>>>>>>>>>>>>>Open and clean-up input datasets
# >>>>>>>>>>>>>>>>>>>Use reproject_match...
# >>>>>>>>>>>>>>>>>>>clean up aster...
# >>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>map results from zonal stats back onto grid
# >>>>>>>>>>>>>>>>>>>compute TB
# >>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>merge all together
# >>>>>>>>>>>>>>>>>>>clip to aster image extent
# >>>>>>>>>>>>>>>>>>>return dataset
# Zonal stats between ASTER and MODIS
# /storage/spestana/ASTER/AST_L1T/geotiff/T/T_band14_Tuolumne-and-CUES/AST_L1T_00306172020055447_20200618110409_10687_ImageData14.tif
# /storage/MODIS/Tuolumne_MOD021KM/MOD021KM.A2020169.0550.061.2020169132726.tif
# >>>>>>>>>>>>>>>>>>>>>>open and clean up aster image
# >>>>>>>>>>>>>>>>>>>>>>open and reproject match MODIS image
# >>>>>>>>>>>>>>>>>>>>>>compute zonal stats
# >>>>>>>>>>>>>>>>>>>>>>map results back onto grid
# >>>>>>>>>>>>>>>>>>>>>>compute brightness temperature
# >>>>>>>>>>>>>>>>>>>>>>merge datasets together
# >>>>>>>>>>>>>>>>>>>>>>compute differences
# >>>>>>>>>>>>>>>>>>>>>>return dataset
# Fixing data variable and attribute names to avoid merge conflicts and invalid characters
# Merging datasets...
# Add time UTC dimension
# Add attributes to dataset
# Export to NetCDF file...
# Moving onto next...
